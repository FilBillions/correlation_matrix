# %%
from covariance_matrix import CovarianceMatrix
from datetime import date, timedelta
import yfinance as yf

# %%
universe = "2024-01-01"

# %%
symbol_list = ['GLD', 'HOOD', 'VTI', 'PYPL', 'V', 'RDDT', 'SPOT', 'NFLX', 'AAPL', 'UVXY']

# %%
test = CovarianceMatrix(symbol_list = symbol_list, start = universe, end = "2025-01-01")
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  10 of 10 completed

# %%
test.generate_covariance_matrix()
# Out:
# Covariance Matrix of Returns:
# Covariance measures the directional relationship between two assets
# Presented as percentages
#            GLD      HOOD       VTI      PYPL         V      RDDT      SPOT  \
# GLD   0.010486  0.026661  0.006056  0.004301  0.002999  0.005726  0.004341
# HOOD  0.026661  0.259735  0.035172  0.020362  0.012432  0.058735   0.04046
# VTI   0.006056  0.035172  0.008718  0.008716  0.005478  0.010001     0.016
# PYPL  0.004301  0.020362  0.008716  0.029273  0.010583  0.047925  0.021576
# V     0.002999  0.012432  0.005478  0.010583   0.01489  0.002613  0.011589
# RDDT  0.005726  0.058735  0.010001  0.047925  0.002613  0.329455  0.005109
# SPOT  0.004341   0.04046     0.016  0.021576  0.011589  0.005109  0.109961
# NFLX  0.005877  0.027933   0.00947  0.015138  0.005907  0.019112  0.028777
# AAPL  0.003593  0.029091  0.007896  0.003189  0.002127  0.009193  0.013809
# UVXY -0.023673  -0.22816 -0.049665 -0.054732 -0.033796 -0.075485 -0.090923
#
#           NFLX      AAPL      UVXY
# GLD   0.005877  0.003593 -0.023673
# HOOD  0.027933  0.029091  -0.22816
# VTI    0.00947  0.007896 -0.049665
# PYPL  0.015138  0.003189 -0.054732
# V     0.005907  0.002127 -0.033796
# RDDT  0.019112  0.009193 -0.075485
# SPOT  0.028777  0.013809 -0.090923
# NFLX  0.019509   0.00702 -0.051147
# AAPL   0.00702  0.018454 -0.052894
# UVXY -0.051147 -0.052894  0.378562

# %%
test.generate_correlation_matrix()
# Out:
# Correlation Matrix of Returns:
# Correlation measures the strength of relationship between two assets
# Presented as percentages
#            GLD      HOOD       VTI      PYPL         V      RDDT      SPOT  \
# GLD        100  3.847943   0.16013  0.208422  0.103638   0.93081  0.407663
# HOOD  0.155347       100  0.186864  0.198234  0.086326  1.918355  0.763441
# VTI   0.192611  5.567507       100  0.463189  0.207609  1.782972  1.647959
# PYPL   0.07466  1.758918   0.13794       100  0.218882  4.662574  1.212708
# V     0.072982   1.50578  0.121544  0.430293       100   0.35643  0.913281
# RDDT  0.029626   1.51239  0.047179  0.414279   0.01611       100  0.085588
# SPOT  0.038875  1.803306  0.130649  0.322837  0.123673  0.256433       100
# NFLX  0.124958  2.955746  0.183573  0.537734  0.149671  2.277598  1.981234
# AAPL  0.078539   3.16495  0.157374  0.116472  0.055416  1.126372  0.977508
# UVXY -0.114259 -5.480667 -0.218562 -0.441368 -0.194377 -2.042146 -1.421087
#
#           NFLX      AAPL      UVXY
# GLD   0.232485  0.138222 -4.124979
# HOOD  0.222011  0.224872 -7.988037
# VTI    0.41082  0.333147 -9.491087
# PYPL  0.358379  0.073427 -5.707878
# V     0.196095  0.068679 -4.941667
# RDDT  0.134871  0.063093  -2.34654
# SPOT   0.35151  0.164052  -4.89239
# NFLX       100  0.198005 -6.533879
# AAPL  0.209323       100 -6.947477
# UVXY -0.336723 -0.338679       100

# %%
test.pairs_closest_to_0()
