# %%
from covariance_matrix import CovarianceMatrix
from datetime import date, timedelta
import yfinance as yf

# %%
universe = "2024-01-01"

# %%
symbol_list = ['GLD', 'HOOD', 'VTI', 'PYPL', 'V', 'RDDT', 'SPOT', 'NFLX', 'AAPL', 'UVXY']

# %%
test = CovarianceMatrix(symbol_list = symbol_list, start = universe, end = "2025-01-01")
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  10 of 10 completed
# --------------------
# Using existing sample.csv with 30 data points.
# --------------------

# %%
test.generate_covariance_matrix()
# Out:
# Covariance Matrix of Returns:
# Covariance measures the directional relationship between two assets
# Presented as percentages
#            GLD      HOOD       VTI      PYPL         V      RDDT      SPOT  \
# GLD   0.009833  0.008569  0.003666  0.000282  0.002422  0.027456  0.010368
# HOOD  0.008569  0.079884  0.011593  0.020383   0.00333  0.057725  0.023411
# VTI   0.003666  0.011593  0.006161  0.003603  0.004191  0.020048  0.004824
# PYPL  0.000282  0.020383  0.003603  0.021118  0.003467  0.016381  0.000614
# V     0.002422   0.00333  0.004191  0.003467  0.011007  0.014757 -0.001908
# RDDT  0.027456  0.057725  0.020048  0.016381  0.014757  0.210527  0.038709
# SPOT  0.010368  0.023411  0.004824  0.000614 -0.001908  0.038709  0.075597
# NFLX  0.004981  0.018782  0.007854  0.005269  0.005438  0.035416    0.0099
# AAPL   0.00112  0.009504  0.006247  0.003817   0.00403  0.010979  0.005927
# UVXY -0.010162 -0.049041 -0.034865 -0.019163 -0.015715 -0.048245 -0.030412
#
#           NFLX      AAPL      UVXY
# GLD   0.004981   0.00112 -0.010162
# HOOD  0.018782  0.009504 -0.049041
# VTI   0.007854  0.006247 -0.034865
# PYPL  0.005269  0.003817 -0.019163
# V     0.005438   0.00403 -0.015715
# RDDT  0.035416  0.010979 -0.048245
# SPOT    0.0099  0.005927 -0.030412
# NFLX  0.020404  0.006402 -0.037885
# AAPL  0.006402  0.014447 -0.043577
# UVXY -0.037885 -0.043577  0.463278

# %%
test.generate_correlation_matrix()
# Out:
# Correlation Matrix of Returns:
# Correlation measures the strength of relationship between two assets
# Presented as percentages
#            GLD      HOOD       VTI      PYPL         V      RDDT      SPOT  \
# GLD        100  0.708263  0.084146  0.011993  0.074314  3.684133  0.833633
# HOOD  0.087184       100  0.093372  0.303916  0.035848  2.717572  0.660449
# VTI   0.134295  1.210589       100  0.193454  0.162429  3.398526  0.490026
# PYPL  0.005585  1.149664  0.056443       100  0.072586  1.499972  0.033665
# V     0.066393  0.260181  0.090927  0.139267       100  1.871666 -0.145019
# RDDT  0.172081  1.031183  0.099464   0.15046  0.097853       100  0.672676
# SPOT  0.108437  0.697908  0.039939  0.009404 -0.021114  1.873312       100
# NFLX  0.100268  1.077753  0.125154  0.155454  0.115831  3.299092   0.55259
# AAPL  0.026793  0.648119  0.118315  0.133848  0.102004  1.215382  0.393162
# UVXY -0.042934  -0.59057 -0.116603 -0.118648 -0.070244  -0.94316 -0.356261
#
#           NFLX      AAPL      UVXY
# GLD   0.208057  0.039363 -2.022736
# HOOD  0.275285  0.117209  -3.42492
# VTI   0.414465  0.277415 -8.767354
# PYPL  0.150204  0.091566 -2.602907
# V     0.214732  0.133885 -2.956637
# RDDT  0.319751  0.083402 -2.075483
# SPOT   0.14915  0.075134 -2.183262
# NFLX       100   0.15623 -5.235029
# AAPL  0.220659       100 -7.156296
# UVXY  -0.23057  -0.22316       100

# %%
test.pairs_closest_to_0()
