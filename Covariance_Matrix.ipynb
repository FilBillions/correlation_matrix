# %%
from covariance_matrix import CovarianceMatrix
from datetime import date, timedelta
import yfinance as yf

# %%
universe = "2024-01-01"

# %%
symbol_list = ['GLD', 'HOOD', 'VTI', 'PYPL', 'V', 'RDDT', 'SPOT', 'NFLX', 'AAPL', 'UVXY']

# %%
test = CovarianceMatrix(symbol_list = symbol_list, start = universe, end = "2025-01-01")
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  10 of 10 completed

# %%
test.generate_covariance_matrix()
# Out:
# Covariance Matrix of Returns:
# Covariance measures the directional relationship between two assets
# Presented as percentages
#            GLD      HOOD       VTI      PYPL         V      RDDT      SPOT  \
# GLD   0.010289  0.005071  0.002349  0.002276  0.000212  0.010983  0.004392
# HOOD  0.005071  0.154933  0.020001  0.027529   0.01328  0.054556  0.024136
# VTI   0.002349  0.020001  0.006981  0.007448  0.004036  0.012908  0.007006
# PYPL  0.002276  0.027529  0.007448  0.036652  0.005922  0.015428  0.008544
# V     0.000212   0.01328  0.004036  0.005922  0.012633  0.010269  0.000435
# RDDT  0.010983  0.054556  0.012908  0.015428  0.010269   0.29387  0.018636
# SPOT  0.004392  0.024136  0.007006  0.008544  0.000435  0.018636   0.05581
# NFLX  0.003883  0.024166  0.007461  0.006853   0.00322  0.025504  0.021364
# AAPL   0.00217   0.01525  0.006461  0.002909  0.002038  0.010953  0.006784
# UVXY -0.009113 -0.156736 -0.048957 -0.057013  -0.03032 -0.071139  -0.04729
#
# ...

# %%
test.generate_correlation_matrix()
# Out:
# Correlation Matrix of Returns:
# Correlation measures the strength of relationship between two assets
# Presented as percentages
#            GLD       HOOD       VTI      PYPL         V       RDDT      SPOT  \
# GLD        100   3.837371  0.377307  0.837797  0.045734  11.445235  1.994702
# HOOD  0.254847        100  0.827868  2.611006  0.739447  14.651626  2.824746
# VTI   0.556149  18.374359       100  3.327796  1.058802  16.331548  3.862632
# PYPL  0.235196  11.037065  0.633799       100  0.677988   8.518854  2.055934
# V     0.037249   9.068614  0.585056  1.967027       100   9.657899  0.178184
# RDDT  0.400738   7.724587  0.387941   1.06249  0.415182        100  1.583658
# SPOT  0.367755   7.841766  0.483133  1.350199  0.040334   8.338853       100
# NFLX   0.42673  10.304505  0.675288  1.421172  0.392008   14.97742  5.467292
# AAPL  0.298952   8.154408  0.733327  0.756432  0.311227   8.066162  2.177013
# ...

# %%
test.pairs_closest_to_0()
