# %%
from portfolio_management import PortfolioManagement
from datetime import date, timedelta
import yfinance as yf

# %% [markdown]
# <h1>Inputs:</h1>

# %% [markdown]
# <h3>Portfolio Holdings Dictionary:</h3>

# %%
portfolio_dictionary = {
    'SPY':1.0,
    'GLD':.0,
    'BTC-USD':.0,
    'UVXY':.0,
    'O':.0,
    'TLT':.0
}

# %%
universe = "2005-01-01"
test = PortfolioManagement(
    portfolio_dictionary = portfolio_dictionary,
    start = universe,
    end = "2025-12-01",
    annualize=True)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  6 of 6 completed
# --------------------
# Using existing sample.csv with 300 data points.
# --------------------

# %% [markdown]
# <h2>Portfolio Basis<h/2>

# %% [markdown]
# __Notes:__

# %%
test.calculate_statistics(return_portfolio_only=True)
# Out:
# Portfolio Comparison to Market:
#                Beta Actual Weight Expected Return  Variance Sharpe Ratio  \
# SPY             1.0           1.0        0.104347  0.011775     0.777307
# Portfolio  0.802582           1.0        0.087695  0.008311     0.742569
#
#           M2 Alpha Treynor Ratio Jensen's Alpha  Non-Systematic Variance  \
# SPY            0.0      0.084347            0.0                      0.0
# Portfolio -0.00377      0.084347      -0.016651                      NaN
#
#           Check 1  Optimized Weightings
# SPY          True              0.774122
# Portfolio     NaN                   NaN

# %% [markdown]
# <h2>Correlation Matrix</h2>

# %%
test.generate_correlation_matrix()
# Out:
# Correlation measures the strength of relationship between two assets
# Closer to 1 means strong positive correlation, closer to -1 means strong negative correlation
# A value of 0 means no correlation

# %% [markdown]
# <h2>Statistic Calculations:</h2>
#
# Various metrics calcuated on individual portfolio holdings.

# %%
test.calculate_statistics()
# Out:
#                Beta Actual Weight Expected Return  Variance Sharpe Ratio  \
# SPY             1.0           1.0        0.104347  0.011775     0.777307
# GLD        0.125999           0.0        0.030628  0.014548     0.088113
# BTC-USD    7.226881           0.0        0.629562  3.085684      0.34701
# UVXY      -2.140322           0.0       -0.160529  0.177169    -0.428896
# O          0.136654           0.0        0.031526   0.02388     0.074589
# TLT        0.010643           0.0        0.020898  0.012683     0.007972
# Portfolio  0.802582           1.0        0.087695  0.008311     0.742569
#
#            M2 Alpha Treynor Ratio Jensen's Alpha  Non-Systematic Variance  \
# SPY             0.0      0.084347            0.0                 0.000000
# GLD       -0.074785      0.312491       0.028746                 0.014361
# BTC-USD   -0.046692      0.135871       0.372364                 2.470719
# UVXY      -0.130887      0.247158      -0.348469                 0.123230
# O         -0.076253      0.289739       0.028068                 0.023660
# TLT       -0.083482     -2.739073      -0.030051                 0.012681
# Portfolio  -0.00377      0.084347      -0.016651                      NaN
#
#            Information Ratio Check 1  Optimized Weightings
# SPY                 0.000000    True              0.774122
# GLD                 2.001718    True              0.225878
# BTC-USD             0.150711   False              0.000000
# UVXY               -2.827804   False              0.000000
# O                   1.186300   False              0.000000
# TLT                -2.369677   False              0.000000
# Portfolio                NaN     NaN                   NaN

# %% [markdown]
# <h2>Determining the addition of a security to the portfolio</h2>
#
# When we add a holding to the portfolio, it has to satisfy certain conditions that would make it a beneficial addition to the portfolio.
#
# 1.) Is the risk-return trade-off greater with the inclusion of this asset? (I.E., is the expected return greater?)
#
# 2.) Does it lie above the SML?
#
# 3.) Does it live bove the SCL?
#
# 4.) A general assessment of correlation to the portfolio

# %%
test.risk_return_tradeoff_test()
# Out:
# GLD:
# Passed Check 1: New Sharpe Ratio is Greater Than Previous Sharpe Ratio * Correlation
# New Expected Return: 0.0306, Old Expected Return: 0.1043
# New Sharpe Ratio: 0.0881, Old Sharpe Ratio: 0.7773
# Passed Check 2: Jensen's Alpha is positive
# --------------------------------------------------
# BTC-USD: Detrimental Addition to Portfolio
# --------------------------------------------------
# UVXY: Detrimental Addition to Portfolio
# --------------------------------------------------
# O: Detrimental Addition to Portfolio
# --------------------------------------------------
# TLT: Detrimental Addition to Portfolio
# --------------------------------------------------
