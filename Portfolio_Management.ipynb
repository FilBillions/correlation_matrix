# %%
from portfolio_management import PortfolioManagement
from datetime import date, timedelta
import yfinance as yf

# %% [markdown]
# <h1>Inputs:</h1>

# %%
universe = "2024-01-01"
symbol_list = ['VTI', 'GLD', 'HOOD', 'PYPL', 'V', 'RDDT', 'SPOT', 'NFLX', 'AAPL', 'NUKK', 'RCAT', 'META', 'UVXY']
test = PortfolioManagement(symbol_list = symbol_list, start = universe, end = "2025-01-01")
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  14 of 14 completed
# --------------------
# Using existing sample.csv with 100 data points.
# --------------------
# {'SPY': 7.198796322356634e-05, 'VTI': 7.64930269684096e-05, 'GLD': 0.00010827984060536682, 'HOOD': 0.0014394352392586966, 'PYPL': 0.00045296164740974066, 'V': 0.00016405990637915037, 'RDDT': 0.002858822714704234, 'SPOT': 0.0006663394880804926, 'NFLX': 0.00024254109185489886, 'AAPL': 0.00021492591290857434, 'NUKK': 0.034565640583982385, 'RCAT': 0.007296152194049688, 'META': 0.0005016150231446806, 'UVXY': 0.004738558695147038}

# %% [markdown]
# <h2>Correlation Matrix</h2>

# %%
test.generate_correlation_matrix()
# Out:
# Correlation measures the strength of relationship between two assets
# Closer to 1 means strong positive correlation, closer to -1 means strong negative correlation
# A value of 0 means no correlation

# %% [markdown]
# <h2>Beta Calculations:</h2>

# %%
test.calculate_beta()
# Out:
#           Beta
# VTI   0.006722
# GLD   0.001388
# HOOD  0.001038
# PYPL  0.001466
# V     0.001713
# RDDT  0.000353
# SPOT  0.000770
# NFLX  0.002192
# AAPL  0.002087
# NUKK -0.000058
# RCAT  0.000059
# META  0.001377
# UVXY -0.000696
