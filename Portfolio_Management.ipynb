# %%
from portfolio_management import PortfolioManagement
from datetime import date, timedelta
import yfinance as yf

# %% [markdown]
# <h1>Inputs:</h1>

# %%
universe = "2024-01-01"
symbol_list = ['VTI', 'GLD', 'HOOD', 'PYPL', 'V', 'RDDT', 'SPOT', 'NFLX', 'AAPL', 'NUKK', 'RCAT', 'META', 'UVXY']
test = PortfolioManagement(symbol_list = symbol_list, start = universe, end = "2025-01-01")
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  14 of 14 completed
# --------------------
# Using existing sample.csv with 100 data points.
# --------------------

# %%
test.generate_covariance_matrix()
# Out:
# Covariance Matrix of Returns:
# Covariance measures the directional relationship between two assets
# Presented as percentages
#            SPY       VTI       GLD      HOOD      PYPL         V      RDDT  \
# SPY   0.005595  0.005626  0.002861  0.009907  0.005849  0.002276  0.012075
# VTI   0.005626  0.005747  0.003005  0.010512   0.00629  0.002397  0.012081
# GLD   0.002861  0.003005  0.010014  0.005222  0.001557  0.000818  0.010702
# HOOD  0.009907  0.010512  0.005222  0.091305  0.021539  0.008022  0.017835
# PYPL  0.005849   0.00629  0.001557  0.021539  0.033578  0.003151  0.006514
# V     0.002276  0.002397  0.000818  0.008022  0.003151  0.009034  0.017895
# RDDT  0.012075  0.012081  0.010702  0.017835  0.006514  0.017895  0.340913
# SPOT   0.00592  0.005829   0.00307  0.011706  0.006555  0.000542  0.019255
# NFLX  0.007007  0.006738  0.003991  0.019936  0.004934  0.003624   0.02763
# AAPL  0.004768  0.004564  0.002052  0.007236  0.004329 -0.000872  0.006359
# ...

# %% [markdown]
# <h2>Correlation Matrix</h2>

# %%
test.generate_correlation_matrix()
# Out:
# Correlation measures the strength of relationship between two assets
# Closer to 1 means strong positive correlation, closer to -1 means strong negative correlation
# A value of 0 means no correlation

# %% [markdown]
# <h2>Beta Calculations:</h2>

# %%
test.calculate_statistics()
# Out:
#           Beta  Expected Return
# VTI   1.005375         0.100430
# GLD   0.511108         0.060889
# HOOD  1.775940         0.162075
# PYPL  1.043328         0.103466
# V     0.405903         0.052472
# RDDT  2.154904         0.192392
# SPOT  1.057463         0.104597
# NFLX  1.252239         0.120179
# AAPL  0.852589         0.088207
# NUKK  2.158093         0.192647
# RCAT  0.514759         0.061181
# META  1.373844         0.129908
# UVXY -5.903451        -0.452276
